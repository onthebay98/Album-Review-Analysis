# %% [markdown]
# Robert Christgau, the self-proclaimed "Dean of American rock critics," is "best known for his terse, letter-graded capsule album reviews, composed in a concentrated, fragmented prose style featuring layered clauses, caustic wit, one-liner jokes, political digressions, and allusions ranging from common knowledge to the esoteric." (https://en.wikipedia.org/wiki/Robert_Christgau)

# %% [markdown]
# For this project, we've scraped two sets of data from Robert Christgau's website (https://www.robertchristgau.com/). First, I'll be comparing his letter scoring over the 50-or-so year period he's been reviewing albums to see if he's become more lenient with his scoring over time. And secondly, I've trained an AI to see if the letter score can be predicted from the capsule review.

# %% [markdown]
# Here's what the text we're scraping looks like:

# %%
from bs4 import BeautifulSoup
import requests

# %%
BeautifulSoup(requests.get("https://www.robertchristgau.com/get_gl.php?g=A%2B").content, "html.parser")
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="/rxgau.css" rel="stylesheet" type="text/css"/>
# <meta content="INDEX,FOLLOW" name="robots"/>
# <title>Robert Christgau: Grade List: A+</title>
# </head>
# <body bgcolor="#e0ffff">
# <table border="0" cellpadding="10" cellspacing="0" width="100%">
# <tr><td bgcolor="#1010e0" colspan="2">
# <p><a class="xlnk" href="/"><img alt="Robert Christgau: Dean of American Rock Critics" class="xlnk" height="47" src="/rxgau.gif" width="287"/></a></p>
# </td></tr>
# <tr><td bgcolor="#1010e0" valign="top">
# <table border="1" cellpadding="3" cellspacing="0">
# <tr><td class="xlnk" nowrap=""><a class="xlnk" href="/cg.php">Consumer Guide:</a><br/>
#   <a class="xlnk" href="/xg/web/cgusers.php">User's Guide</a><br/>
#   <a class="xlnk" href="/xg/bk-cg90/grades-90s.php">Grades 1990-</a><br/>
# ...

# %%
BeautifulSoup(requests.get("https://www.robertchristgau.com/get_gl.php?g=A%2B").content, "html.parser").get_text()
# Out:
# "\n\n\n\n\n\nRobert Christgau: Grade List: A+\n\n\n\n\n\n\n\n\nConsumer Guide:\n\xa0\xa0User's Guide\n\xa0\xa0Grades 1990-\n\xa0\xa0Grades 1969-89\n\xa0\xa0And It Don't Stop\nBooks:\n\xa0\xa0Book Reports\n\xa0\xa0Is It Still Good to Ya?\n\xa0\xa0Going Into the City\n\xa0\xa0Consumer Guide: 90s\n\xa0\xa0Grown Up All Wrong\n\xa0\xa0Consumer Guide: 80s\n\xa0\xa0Consumer Guide: 70s\n\xa0\xa0Any Old Way You Choose It\n\xa0\xa0Don't Stop 'til You Get Enough\nXgau Sez\nWritings:\n\xa0\xa0And It Don't Stop\n\xa0\xa0CG Columns\n\xa0\xa0Rock&Roll&\xa0[new]\n\xa0\xa0Rock&Roll&\xa0[old]\n\xa0\xa0Music Essays\n\xa0\xa0Music Reviews\n\xa0\xa0Book Reviews\n\xa0\xa0NAJP Blog\n\xa0\xa0Playboy\n\xa0\xa0Blender\n\xa0\xa0Rolling Stone\n\xa0\xa0Billboard\n\xa0\xa0Video Reviews\n\xa0\xa0Pazz & Jop\n\xa0\xa0Recyclables\n\xa0\xa0Newsprint\n\xa0\xa0Lists\n\xa0\xa0Miscellany\nBibliography\nNPR\nWeb Site:\n\xa0\xa0Home\n\xa0\xa0Site Map\n\xa0\xa0Contact\n\xa0\xa0What's New?\n\xa0\xa0\xa0\xa0RSS\nCarola Dibbell
# ...

# %%
BeautifulSoup(requests.get("https://www.robertchristgau.com/get_gl.php?g=S").content, "html.parser").get_text().split("\n")
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Robert Christgau: Grade List: S',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Consumer Guide:',
#  "\xa0\xa0User's Guide",
#  '\xa0\xa0Grades 1990-',
#  '\xa0\xa0Grades 1969-89',
#  "\xa0\xa0And It Don't Stop",
#  'Books:',
#  '\xa0\xa0Book Reports',
#  '\xa0\xa0Is It Still Good to Ya?',
#  '\xa0\xa0Going Into the City',
#  '\xa0\xa0Consumer Guide: 90s',
#  '\xa0\xa0Grown Up All Wrong',
#  '\xa0\xa0Consumer Guide: 80s',
#  '\xa0\xa0Consumer Guide: 70s',
#  '\xa0\xa0Any Old Way You Choose It',
#  "\xa0\xa0Don't Stop 'til You Get Enough",
#  'Xgau Sez',
#  'Writings:',
#  "\xa0\xa0And It Don't Stop",
#  '\xa0\xa0CG Columns',
#  '\xa0\xa0Rock&Roll&\xa0[new]',
#  '\xa0\xa0Rock&Roll&\xa0[old]',
#  '\xa0\xa0Music Essays',
#  '\xa0\xa0Music Reviews',
#  '\xa0\xa0Book Reviews',
#  '\xa0\xa0NAJP Blog',
#  '\xa0\xa0Playboy',
#  '\xa0\xa0Blender',
#  '\xa0\xa0Rolling Stone',
#  '\xa0\xa0Billboard',
#  '\xa0\xa0Video Reviews',
# ...
